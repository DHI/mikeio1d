# %% [markdown]
# # Res1D - export to shapefile
#
# ## Export to GeoDataFrame

# %%
import mikeio1d

# %%
res = mikeio1d.open("../data/network.res1d")
gdf = res.network.to_geopandas()
gdf.plot()

# %%
res = mikeio1d.open("../data/network.res1d")
gdf = res.network.to_geopandas()
gdf.head()
# Out:
# </div>

# %% [markdown]
# ## Plotting results

# %%
df_reaches = res.reaches.to_geopandas(agg='max')
df_reaches.plot(column='max_Discharge', cmap="RdYlGn_r", legend=True)

# %%
df_nodes = res.nodes.to_geopandas(agg='max')
ax = df_reaches.plot(color="gray", zorder=-1)
df_nodes.plot(ax=ax, column='max_WaterLevel', legend=True)

# %%
res = mikeio1d.open("../data/catchments.res1d")
df_catchments = res.catchments.to_geopandas('max')
df_catchments.plot(column='max_TotalRunOff', cmap='Blues', legend=True, alpha=0.75)

# %% [markdown]
# ## Interactive maps

# %%
map = df_reaches.explore(column="max_Discharge", legend=True, tiles="cartodb positron", tooltip=["name", "max_Discharge"], popup=True)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e802d01bb8d56b114a09574f24bf638b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e802d01bb8d56b114a09574f24bf638b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e802d01bb8d56b114a09574f24bf638b = L.map(
#                 &quot;map_e802d01bb8d56b114a09574f24bf638b&quot;,
#                 {
#                     center: [-1056366.4501953125, -687695.2000427246],
#                     crs: L.CRS.Simple,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_e802d01bb8d56b114a09574f24bf638b);
#
#
#
#
#
#             map_e802d01bb8d56b114a09574f24bf638b.fitBounds(
#                 [[-1056709.4993896484, -688020.8009033203], [-1056023.4010009766, -687369.5991821289]],
#                 {}
#             );
#
#
#         function geo_json_833f24b375ac28fcae6e6378a58639e9_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;114&quot;:
#                     return {&quot;color&quot;: &quot;#481769&quot;, &quot;fillColor&quot;: &quot;#481769&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;34&quot;:
#                     return {&quot;color&quot;: &quot;#450559&quot;, &quot;fillColor&quot;: &quot;#450559&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#414487&quot;, &quot;fillColor&quot;: &quot;#414487&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;4&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;11&quot;: case &quot;26&quot;: case &quot;38&quot;: case &quot;44&quot;: case &quot;49&quot;: case &quot;64&quot;: case &quot;65&quot;: case &quot;70&quot;: case &quot;72&quot;: case &quot;73&quot;: case &quot;75&quot;: case &quot;77&quot;: case &quot;81&quot;: case &quot;85&quot;: case &quot;86&quot;: case &quot;87&quot;: case &quot;90&quot;: case &quot;94&quot;: case &quot;95&quot;: case &quot;111&quot;:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;29&quot;: case &quot;45&quot;: case &quot;46&quot;: case &quot;47&quot;:
#                     return {&quot;color&quot;: &quot;#482173&quot;, &quot;fillColor&quot;: &quot;#482173&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#424086&quot;, &quot;fillColor&quot;: &quot;#424086&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;: case &quot;52&quot;:
#                     return {&quot;color&quot;: &quot;#471365&quot;, &quot;fillColor&quot;: &quot;#471365&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;: case &quot;36&quot;: case &quot;55&quot;: case &quot;61&quot;: case &quot;63&quot;: case &quot;110&quot;:
#                     return {&quot;color&quot;: &quot;#440256&quot;, &quot;fillColor&quot;: &quot;#440256&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;#472a7a&quot;, &quot;fillColor&quot;: &quot;#472a7a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;15&quot;: case &quot;109&quot;:
#                     return {&quot;color&quot;: &quot;#481467&quot;, &quot;fillColor&quot;: &quot;#481467&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillO

# %%
# save a distributable html map
map.save("results.html")

# %% [markdown]
# ## Export to shapefile

# %%
for df in [df_reaches, df_nodes, df_catchments]:
    df.columns = [col[:10] for col in df.columns]

df_reaches.to_file("reaches.shp")
df_nodes.to_file("nodes.shp")
df_catchments.to_file("catchments.shp")

# %% [markdown]
# ``` python
# from pathlib import Path
#
# files_to_delete = []
# for p in ("results.html", "reaches*", "nodes*", "catchments*"):
#     files_to_delete = [*files_to_delete, *Path.glob(Path.cwd(), p)]
#
# for f in files_to_delete:
#     f.unlink()
# ```
