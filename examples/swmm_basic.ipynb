# %% [markdown]
# # SWMM - basic
#
# ## Overview
#
# > **Tip**
# >
# > MIKE IO 1D treats SWMM and Res1D results in the same way, so you may
# > also refer to Res1D examples.

# %%
import mikeio1d

# %%
res = mikeio1d.open("../data/swmm.out")
res.info()
# Out:
# Start time: 1998-01-01 01:00:00.001000
# End time: 1998-01-02 12:00:00.001000
# # Timesteps: 36
# # Catchments: 8
# # Nodes: 14
# # Reaches: 13
# # Globals: 15
# 0 - Water depth (ft)
# 1 - Hydraulic head (ft)
# 2 - Volume stored & ponded (ft^3)
# 3 - Lateral inflow rate (ft^3/s)
# 4 - Total inflow rate (ft^3/s)
# 5 - Overflow rate (ft^3/s)
# 6 - TSS concentration (mu-g/l)
# 7 - Discharge (ft^3/s)
# 8 - Water Depth (ft)
# 9 - Velocity (ft/s)
# 10 - Volume (())
# 11 - Capacity (())
# 12 - TSS concentration (mu-g/l)
# 13 - Rainfall intensity (in/h)
# 14 - Snow depth (in)
# 15 - Evap loss (in)
# 16 - Infil loss (in/h)
# 17 - Runoff flow (ft^3/s)
# 18 - Groundwater flow (ft^3/s)
# 19 - Elevation of saturated gw table (ft)
# 20 - Soil moisture (())
# 21 - TSS Washoff (mu-g/l)
# 22 - Air temperature (deg F)
# 23 - Rainfall intensity (in/h)
# 24 - Snow depth (in)
# 25 - Infil (in/h)
# 26 - Runoff flow (ft^3/s)
# 27 - Dry weather inflow (ft^3/s)
# 28 - Ground water inflow (ft^3/s)
# 29 - RDII inflow (ft^3/s)
# 30 - External inflow (ft^3/s)
# 31 - Flooding outflow (ft^3/s)
# 32 - Outfall outflow (ft^3/s)
# 33 - Storage volume (ft^3)
# 34 - Evaporation (-)
# 35 - Potential ET (-)

# %% [markdown]
# ## Plot network

# %%
ax = res.reaches.to_geopandas().plot()
res.nodes.to_geopandas().plot(ax=ax)
res.catchments.to_geopandas().plot(ax=ax, alpha=0.5)

# %% [markdown]
# ## Explore network

# %%
res.reaches
# Out:
# &lt;ResultReaches&gt; (13)
#     <style>
#         ul {
#             margin: 0px;
#             padding: 0px;
#             padding-left: 2em;
#         }
#     </style>
#     <details><summary>Quantities (6)</summary><ul><li>Discharge (ft^3/s)</li><li>Water Depth (ft)</li><li>Velocity (ft/s)</li><li>Volume (())</li><li>Capacity (())</li><li>TSS concentration (mu-g/l)</li></ul></details><details><summary>Derived Quantities (0)</summary><ul></ul></details>

# %%
res.nodes
# Out:
# &lt;ResultNodes&gt; (14)
#     <style>
#         ul {
#             margin: 0px;
#             padding: 0px;
#             padding-left: 2em;
#         }
#     </style>
#     <details><summary>Quantities (7)</summary><ul><li>Water depth (ft)</li><li>Hydraulic head (ft)</li><li>Volume stored & ponded (ft^3)</li><li>Lateral inflow rate (ft^3/s)</li><li>Total inflow rate (ft^3/s)</li><li>Overflow rate (ft^3/s)</li><li>TSS concentration (mu-g/l)</li></ul></details><details><summary>Derived Quantities (0)</summary><ul></ul></details>

# %%
res.catchments
# Out:
# &lt;ResultCatchments&gt; (8)
#     <style>
#         ul {
#             margin: 0px;
#             padding: 0px;
#             padding-left: 2em;
#         }
#     </style>
#     <details><summary>Quantities (9)</summary><ul><li>Rainfall intensity (in/h)</li><li>Snow depth (in)</li><li>Evap loss (in)</li><li>Infil loss (in/h)</li><li>Runoff flow (ft^3/s)</li><li>Groundwater flow (ft^3/s)</li><li>Elevation of saturated gw table (ft)</li><li>Soil moisture (())</li><li>TSS Washoff (mu-g/l)</li></ul></details><details><summary>Derived Quantities (0)</summary><ul></ul></details>

# %% [markdown]
# ## Extract results to a DataFrame

# %%
df = res.read()
df.head()
# Out:
# <p>5 rows × 298 columns</p>
# </div>

# %%
df = res.reaches['1'].SWMM_LINK_FLOW.read()
df.head()
# Out:
# </div>

# %% [markdown]
# ## Plot results

# %%
res.reaches['1'].SWMM_LINK_FLOW.plot()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2)
res.reaches['1'].SWMM_LINK_FLOW.plot(ax=ax[0])
res.catchments['2'].SWMM_SUBCATCH_RUNOFF.plot(ax=ax[1])

plt.tight_layout()
