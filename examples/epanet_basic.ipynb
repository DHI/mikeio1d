# %% [markdown]
# # EPANET - basic
#
# ## Overview
#
# > **Tip**
# >
# > MIKE IO 1D treats EPANET (.res/.resx) and Res1D results in the same
# > way, so you may also refer to Res1D examples.

# %%
import mikeio1d

# %% [markdown]
# > **Caution**
# >
# > Reading ‘.res’ files requires the accompanying ‘.inp’ file having the
# > same name.

# %%
res = mikeio1d.open("../data/epanet.res")
res.info()
# Out:
# Start time: 2022-10-13 00:00:00
# End time: 2022-10-14 00:00:00
# # Timesteps: 25
# # Catchments: 0
# # Nodes: 11
# # Reaches: 13
# # Globals: 0
# 0 - Water Demand (l/s)
# 1 - Head (m)
# 2 - Pressure (m)
# 3 - Water Quality (-)
# 4 - Flow (l/s)
# 5 - Velocity (m/s)
# 6 - Headloss Per 1000Unit (m)
# 7 - Average Water Quality (-)
# 8 - Status Code (-)
# 9 - Setting (-)
# 10 - Reactor Rate (-)
# 11 - Friction Factor (-)

# %% [markdown]
# ## Plot network

# %%
res.network.to_geopandas().plot()

# %% [markdown]
# ## Explore network

# %%
res.reaches
# Out:
# &lt;ResultReaches&gt; (13)
#     <style>
#         ul {
#             margin: 0px;
#             padding: 0px;
#             padding-left: 2em;
#         }
#     </style>
#     <details><summary>Quantities (8)</summary><ul><li>Flow (l/s)</li><li>Velocity (m/s)</li><li>Headloss Per 1000Unit (m)</li><li>Average Water Quality (-)</li><li>Status Code (-)</li><li>Setting (-)</li><li>Reactor Rate (-)</li><li>Friction Factor (-)</li></ul></details><details><summary>Derived Quantities (0)</summary><ul></ul></details>

# %%
res.nodes
# Out:
# &lt;ResultNodes&gt; (11)
#     <style>
#         ul {
#             margin: 0px;
#             padding: 0px;
#             padding-left: 2em;
#         }
#     </style>
#     <details><summary>Quantities (4)</summary><ul><li>Water Demand (l/s)</li><li>Head (m)</li><li>Pressure (m)</li><li>Water Quality (-)</li></ul></details><details><summary>Derived Quantities (0)</summary><ul></ul></details>

# %% [markdown]
# ## Extract results to a DataFrame

# %%
df = res.read()
df.head()
# Out:
# <p>5 rows × 148 columns</p>
# </div>

# %%
df = res.reaches.Flow.read()
df.head()
# Out:
# </div>

# %% [markdown]
# ## Plot results

# %%
res.reaches['110'].Flow.plot()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2)
res.reaches['110'].Flow.plot(ax=ax[0])
res.reaches['110'].Velocity.plot(ax=ax[1])

plt.tight_layout()
