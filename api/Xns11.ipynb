# %% [markdown]
# #
#
# # Xns11
#
# ``` python
# Xns11(self, file_path=None, *args, **kwargs)
# ```
#
# A class to read and write xns11 files.
#
# ## Parameters
#
# | Name      | Type        | Description                                | Default |
# |-----------|-------------|---------------------------------------|-----------|
# | file_path | str \| Path | full path and file name to the xns11 file. | `None`  |
#
# ## Notes
#
# The Xns11 class is a subclass of CrossSectionCollection. The main
# difference is that Xns11 has a file_path property to track where the
# file was last loaded from or saved to.
#
# ## Examples
#
# ``` python
# # Open an existing file
# >>> xns = Xns11("file.xns11")
#
# # Overview of the cross sections
# >>> xns.to_dataframe()
#
# # Read a specific cross section
# >>> xs = xns.sel(location_id='basin_left1', chainage='122.042', topo_id='1')
#
# # Plot a cross section
# >>> xs.plot()
#
# # Access cross section raw data
# >>> xs.raw_data
#
# # Access cross section processed data
# >>> xs.processed_data
# ```
#
# ## Attributes
#
# | Name | Description |
# |------------------------------------|------------------------------------|
# | [chainages](#mikeio1d.Xns11.chainages) | Unique chainages in the collection (as string with 3 decimals). |
# | [cross_section_data](#mikeio1d.Xns11.cross_section_data) | The DHI.Mike1D.CrossSectionModule.CrossSectionData object. |
# | [data](#mikeio1d.Xns11.data) | The DHI.Mike1D.CrossSectionModule.CrossSectionData object. |
# | [file](#mikeio1d.Xns11.file) | Alias for CrossSectionData objected stored on the member ’\_cross_section_data’. |
# | [file_path](#mikeio1d.Xns11.file_path) | Full path and file name to the xns11 file. |
# | [interpolation_type](#mikeio1d.Xns11.interpolation_type) | Defines how an interpolated cross section is interpolated. |
# | [location_ids](#mikeio1d.Xns11.location_ids) | Unique location IDs in the collection. |
# | [reach_names](#mikeio1d.Xns11.reach_names) | A list of the reach names. |
# | [topo_ids](#mikeio1d.Xns11.topo_ids) | Unique topo IDs in the collection. |
# | [topoid_names](#mikeio1d.Xns11.topoid_names) | A list of the topo-id names. |
# | [xns11](#mikeio1d.Xns11.xns11) | Deprecated. Only use CrossSectionCollection instead. |
# | [xsections](#mikeio1d.Xns11.xsections) | A collection of CrossSection objects. |
#
# ## Methods
#
# | Name | Description |
# |------------------------------------|------------------------------------|
# | [add](#mikeio1d.Xns11.add) | Add a cross section to the collection. |
# | [add_xsection](#mikeio1d.Xns11.add_xsection) | Add a cross section to the collection. |
# | [close](#mikeio1d.Xns11.close) | Close the file handle. |
# | [from_cross_section_collection](#mikeio1d.Xns11.from_cross_section_collection) | Create a Xns11 object from a CrossSectionCollection. |
# | [get_supported_file_extensions](#mikeio1d.Xns11.get_supported_file_extensions) | Get supported file extensions for Xns11. |
# | [info](#mikeio1d.Xns11.info) | Print information about the file. |
# | [plot](#mikeio1d.Xns11.plot) | Plot all cross sections in the collection. |
# | [read](#mikeio1d.Xns11.read) | Read the requested data from the xns11 file and return a Pandas DataFrame. |
# | [remove](#mikeio1d.Xns11.remove) | Remove a cross section from the collection. |
# | [sel](#mikeio1d.Xns11.sel) | Select cross sections from the collection. |
# | [to_dataframe](#mikeio1d.Xns11.to_dataframe) | Convert the collection to a DataFrame. |
# | [to_geopandas](#mikeio1d.Xns11.to_geopandas) | Convert the collection to a GeoDataFrame. |
# | [to_xns11](#mikeio1d.Xns11.to_xns11) | Save the collection to an Xns11 file. |
# | [write](#mikeio1d.Xns11.write) | Write cross section data to an xns11 file. |
#
# ### add
#
# ``` python
# Xns11.add(cross_section)
# ```
#
# Add a cross section to the collection.
#
# #### Parameters
#
# | Name          | Type         | Description           | Default    |
# |---------------|--------------|-----------------------|------------|
# | cross_section | CrossSection | Cross section to add. | *required* |
#
# ### add_xsection
#
# ``` python
# Xns11.add_xsection(xsection)
# ```
#
# Add a cross section to the collection.
#
# ### close
#
# ``` python
# Xns11.close()
# ```
#
# Close the file handle.
#
# ### from_cross_section_collection
#
# ``` python
# Xns11.from_cross_section_collection(xsections)
# ```
#
# Create a Xns11 object from a CrossSectionCollection.
#
# ### get_supported_file_extensions
#
# ``` python
# Xns11.get_supported_file_extensions()
# ```
#
# Get supported file extensions for Xns11.
#
# ### info
#
# ``` python
# Xns11.info()
# ```
#
# Print information about the file.
#
# ### plot
#
# ``` python
# Xns11.plot(*args, **kwargs)
# ```
#
# Plot all cross sections in the collection.
#
# ### read
#
# ``` python
# Xns11.read(queries)
# ```
#
# Read the requested data from the xns11 file and return a Pandas
# DataFrame.
#
# #### Parameters
#
# | Name    | Type | Description                                         | Default    |
# |---------|--------|---------------------------------------------|-----------|
# | queries |      | `QueryData` objects that define the requested data. | *required* |
#
# #### Returns
#
# | Name | Type         | Description |
# |------|--------------|-------------|
# |      | pd.DataFrame |             |
#
# ### remove
#
# ``` python
# Xns11.remove(cross_section)
# ```
#
# Remove a cross section from the collection.
#
# #### Parameters
#
# | Name          | Type         | Description              | Default    |
# |---------------|--------------|--------------------------|------------|
# | cross_section | CrossSection | Cross section to remove. | *required* |
#
# ### sel
#
# ``` python
# Xns11.sel(location_id=..., chainage=..., topo_id=...)
# ```
#
# Select cross sections from the collection.
#
# #### Parameters
#
# | Name        | Type         | Description                       | Default |
# |-------------|--------------|-----------------------------------|---------|
# | location_id | str          | Location ID of the cross section. | `...`   |
# | chainage    | str \| float | Chainage of the cross section.    | `...`   |
# | topo_id     | str          | Topo ID of the cross section.     | `...`   |
#
# #### Returns
#
# | Name | Type | Description |
# |----|---------------|------------------------------------------------------|
# |  | CrossSection or list\[CrossSection\] | Providing all arguments will return a CrossSection. Provinding partial arguments will always return a list, even if it only includes one CrossSection. |
#
# ### to_dataframe
#
# ``` python
# Xns11.to_dataframe()
# ```
#
# Convert the collection to a DataFrame.
#
# ### to_geopandas
#
# ``` python
# Xns11.to_geopandas(mode='sections')
# ```
#
# Convert the collection to a GeoDataFrame.
#
# #### Parameters
#
# | Name | Type | Description | Default |
# |------|------|---------------------------------------------------|----------|
# | mode | str | Mode of conversion. Options are “sections” and “markers”. Default is “sections”. | `'sections'` |
#
# #### Returns
#
# | Name | Type             | Description                                      |
# |------|------------------|--------------------------------------------------|
# |      | gpd.GeoDataFrame | GeoDataFrame with the cross sections or markers. |
#
# #### Note:
#
# This method requires the geopandas package to be installed. Cross
# sections must have defined coordinates.
#
# ### to_xns11
#
# ``` python
# Xns11.to_xns11(file_name, **kwargs)
# ```
#
# Save the collection to an Xns11 file.
#
# #### Parameters
#
# | Name      | Type        | Description               | Default    |
# |-----------|-------------|---------------------------|------------|
# | file_name | str or Path | Path to the file to save. | *required* |
#
# #### Examples
#
# ``` python
# >>> csc.to_xns11("cross_sections.xns11")
# ```
#
# ### write
#
# ``` python
# Xns11.write(file_path=None)
# ```
#
# Write cross section data to an xns11 file.
#
# #### Parameters
#
# | Name | Type | Description | Default |
# |-------|--------|---------------------------------------------------|-------|
# | file_path | str \| Path | Full file path of the xns11 file to be written. Default is the file_path used to open the file. | `None` |
