# %% [markdown]
# # Quantities
#
# ``` python
# from mikeio1d import Res1D
# res = Res1D('../data/network.res1d')
# res_catchments = Res1D('../data/catchments.res1d')
# ```
#
# [Quantities](../api/result_network.ResultQuantity.html#mikeio1d.result_network.ResultQuantity)
# are the actual model results, which can be read into a pandas DataFrame
# or plotted directly.
#
# ## Data structures
#
# Two main quantity structures exist:
# [quantities](../api/result_network.ResultQuantity.html#mikeio1d.result_network.ResultQuantity)
# and [quantity
# collections](../api/result_network.ResultQuantityCollection.html#mikeio1d.result_network.ResultQuantityCollection).
#
# ### Quantity
#
# A quantity is a single quantity at a specific location. Quantities are
# accessed from a location object.

# %%
res.nodes['101'].WaterLevel # single quantity (i.e. water level) at a single location (i.e. node 101)
# Out:
# <Quantity: Water level (m)>

# %% [markdown]
# ### Quantity Collection
#
# A quantity collection is a single quantity at multiple locations.
# Quantity collections are accessed from a location collection.

# %%
res.nodes.WaterLevel # single quantity (i.e. water level) at multiple locations (i.e. all nodes)
# Out:
# <QuantityCollection (119): Water level (m)>

# %% [markdown]
# ## Reading data
#
# Quantities and quantity collections can be read into a pandas DataFrame
# with their `read` method.

# %%
df = res.nodes['101'].WaterLevel.read()
df.head()
# Out:
# </div>

# %%
df = res.nodes.WaterLevel.read()
df.head()
# Out:
# <p>5 rows × 119 columns</p>
# </div>

# %% [markdown]
# ## Plotting data
#
# Quantities and quantity collections can be plotted directly with their
# `plot` method.

# %%
res.nodes['101'].WaterLevel.plot()

# %%
res.nodes.WaterLevel.plot(legend=False)

# %% [markdown]
# ## Dynamic selections
#
# Quantities or quantity collections can be conveniently combined into a
# single DataFrame with the ‘add’ method.

# %%
res.nodes['101'].WaterLevel.add()
res.nodes['100'].WaterLevel.add()
df = res.read()
df.head()
# Out:
# </div>

# %%
res.nodes.WaterLevel.add()
res.reaches.WaterLevel.add()
df = res.read()
df.head()
# Out:
# <p>5 rows × 366 columns</p>
# </div>

# %% [markdown]
# > **Note**
# >
# > The name ‘add’ indicates the quantity is added to a list of quantities
# > to be read. The ‘read’ method reads all quantities in the list.
#
# ## Examples
#
# -   [Res1D Basics](../examples/res1d_basic.qmd)
#
# > **Tip**
# >
# > There are also several notebook examples available on our [GitHub
# > repository]()https://github.com/DHI/mikeio1d/tree/main/notebooks.
